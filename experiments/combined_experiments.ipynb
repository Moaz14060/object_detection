# %% [markdown]
# - **`Model`: Yolov8s**
# - **`Dataset`: Roboflow & Kaggle & Sub-part of 24 class coco**

# %%
from ultralytics import YOLO

# %%
data_path = r"F:\object_detection\data\fixed_data.yaml"
# Quick check: open data.yaml file
with open(data_path, "r") as f:
    print(f.read())
# Out:
# train: F:/object_detection/data/data1/train_balanced/images
# val: F:/object_detection/data/data1/valid/images
# test: F:/object_detection/data/data1/test/images
#
# nc: 27
# names:
#   0: biker
#   1: car
#   2: person
#   3: trafficLight
#   4: trafficLight-Green
#   5: trafficLight-GreenLeft
#   6: trafficLight-Red
#   7: trafficLight-RedLeft
#   8: trafficLight-Yellow
#   9: trafficLight-YellowLeft
#   10: truck
#   11: bus
#   12: motorcycle
#   13: train
#   14: boat
#   15: bicycle
#   16: umbrella
#   17: suitcase
#   18: handbag
#   19: backpack
#   20: bench
#   21: skateboard
#   22: stop sign
#   23: fire hydrant
#   24: parking meter
#   25: animal
#   26: speed sign

# %%
# To check if the GPU is used intead of the CPU
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA available: True
# GPU Name: NVIDIA GeForce GTX 1660 SUPER

# %% [markdown]
# ## **First Run**

# %%
# Training
model = YOLO(r"F:\object_detection\experiments\runs\detect\train\weights\last.pt")

results = model.train(resume = True)
# Out:
# New https://pypi.org/project/ultralytics/8.3.224 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.199  Python-3.12.4 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# ...

# %% [markdown]
# ## **Second Run**

# %%
model = YOLO(r"F:\object_detection\experiments\runs\detect\train\weights\best.pt")

model.train(
    data=data_path,   
    epochs=50,       
    imgsz=640,        
    batch=9,
    device=0,          
    augment=True)
# Out:
# New https://pypi.org/project/ultralytics/8.3.225 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.199  Python-3.12.4 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# ...

# %%
model = YOLO(r"F:\object_detection\experiments\runs\detect\train2\weights\last.pt")

model.train(resume = True)
# Out:
# New https://pypi.org/project/ultralytics/8.3.226 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.199  Python-3.12.4 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# ...

# %% [markdown]
# ## **Third Run**

# %% [markdown]
# - Trying again without augmentation since it lowered the accuracy

# %%
model = YOLO(r"F:\object_detection\experiments\runs\detect\train\weights\best.pt")

model.train(
    data=data_path,   
    epochs=50,       
    imgsz=640,        
    batch=9,
    device=0
    )
# Out:
# New https://pypi.org/project/ultralytics/8.3.228 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.199  Python-3.12.4 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# ...

# %%
model = YOLO(r"F:\object_detection\experiments\runs\detect\train3\weights\last.pt")
model.train(resume = True)
# Out:
# Ultralytics 8.3.199  Python-3.12.4 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# ...

# %% [markdown]
# ---
# # <center>Exporting Model to "onnx" Format<center>
# ---

# %% [markdown]
# - **`Note`: this requires Nvidia GPU and a fast live feed from 30 to 45 fps not streamlit**

# %%
model  = YOLO(r"F:\object_detection\experiments\runs\detect\train\weights\best.pt")
model.export(format = "onnx", opset = 12)
# Out:
# Ultralytics 8.3.199  Python-3.12.4 torch-2.7.1+cu118 CPU (Intel Core i5-9400 2.90GHz)
# Model summary (fused): 72 layers, 11,136,033 parameters, 0 gradients, 28.5 GFLOPs
#
# PyTorch: starting from 'F:\object_detection\experiments\runs\detect\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 31, 8400) (21.5 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 12...
# ONNX: slimming with onnxslim 0.1.75...
# ONNX: export success  2.7s, saved as 'F:\object_detection\experiments\runs\detect\train\weights\best.onnx' (42.7 MB)
#
# Export complete (3.3s)
# Results saved to F:\object_detection\experiments\runs\detect\train\weights
# Predict:         yolo predict task=detect model=F:\object_detection\experiments\runs\detect\train\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=F:\object_detection\experiments\runs\detect\train\weights\best.onnx imgsz=640 data=F:\object_detection\data\fixed_data.yaml
# ...
